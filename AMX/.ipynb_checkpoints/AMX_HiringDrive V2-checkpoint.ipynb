# %%
import pandas as pd

# %%
Test=pd.read_csv('test.csv')

# %%
Test.head()
# Out:
#    session_id          DateTime  user_id product  campaign_id  webpage_id  \
# 0      411705  2017-07-08 00:00   732573       J       404347       53587
# 1      208263  2017-07-08 00:00   172910       I       118601       28529
# 2      239450  2017-07-08 00:00   172910       I       118601       28529
# 3      547761  2017-07-08 00:00   557318       G       118601       28529
# 4      574275  2017-07-08 00:00   923896       H       118601       28529
#
#    product_category_1  product_category_2  user_group_id  gender  age_level  \
# 0                   1                 NaN            5.0    Male        5.0
# 1                   3             82527.0            NaN     NaN        NaN
# 2                   4             82527.0            NaN     NaN        NaN
# 3                   5             82527.0            1.0    Male        1.0
# 4                   5             82527.0            9.0  Female        3.0
#
#    user_depth  city_development_index  var_1
# ...

# %%
train=pd.read_csv('train.csv')

# %%
train.head()
# Out:
#    session_id          DateTime  user_id product  campaign_id  webpage_id  \
# 0      140690  2017-07-02 00:00   858557       C       359520       13787
# 1      333291  2017-07-02 00:00   243253       C       105960       11085
# 2      129781  2017-07-02 00:00   243253       C       359520       13787
# 3      464848  2017-07-02 00:00  1097446       I       359520       13787
# 4       90569  2017-07-02 00:01   663656       C       405490       60305
#
#    product_category_1  product_category_2  user_group_id  gender  age_level  \
# 0                   4                 NaN           10.0  Female        4.0
# 1                   5                 NaN            8.0  Female        2.0
# 2                   4                 NaN            8.0  Female        2.0
# 3                   3                 NaN            3.0    Male        3.0
# 4                   3                 NaN            2.0    Male        2.0
#
#    user_depth  city_development_index  var_1  is_click
# ...

# %%
hist = pd.read_csv('historical_user_logs.csv')

# %%
hist.tail()
# Out:
#                   DateTime  user_id product action
# 24287529  2017-07-01 23:59   661885       D   view
# 24287530  2017-07-01 23:59   295226       I   view
# 24287531  2017-07-01 23:59  1100817       B   view
# 24287532  2017-07-01 23:59   820601       G   view
# 24287533  2017-07-01 23:59   524203       H   view

# %%
hist.head()
# Out:
#            DateTime  user_id product action
# 0  2017-05-28 15:44      704       B   view
# 1  2017-05-29 07:08   499679       F   view
# 2  2017-05-29 07:10   499679       G   view
# 3  2017-05-29 07:10   499679       G   view
# 4  2017-05-29 07:10   499679       G   view

# %%
HIST_ID_858557=hist[hist['user_id']==858557]

# %%
HIST_ID_858557.head()
# Out:
#                  DateTime  user_id product action
# 1481425  2017-06-18 19:42   858557       D   view
# 1504899  2017-06-18 19:53   858557       D   view
# 1538435  2017-06-18 20:07   858557       D   view
# 1540802  2017-06-18 20:08   858557       D   view
# 1543075  2017-06-18 20:09   858557       D   view

# %%
TRAIN_ID_858557=train[train['user_id']==858557]
TRAIN_ID_858557.head()
# Out:
#         session_id          DateTime  user_id product  campaign_id  \
# 0           140690  2017-07-02 00:00   858557       C       359520
# 389894      252642  2017-07-06 22:09   858557       I       396664
#
#         webpage_id  product_category_1  product_category_2  user_group_id  \
# 0            13787                   4                 NaN           10.0
# 389894       51181                   1                 NaN           10.0
#
#         gender  age_level  user_depth  city_development_index  var_1  is_click
# 0       Female        4.0         3.0                     3.0      0         0
# 389894  Female        4.0         3.0                     3.0      0         0

# %%
clickisOne=train[train['is_click']==1]

# %%
clickisOne
# Out:
#         session_id          DateTime  user_id product  campaign_id  \
# 38          489923  2017-07-02 00:05   929999       H       359520
# 54          419802  2017-07-02 00:07   740951       G        98970
# 65          145098  2017-07-02 00:08  1005580       C       359520
# 106         102183  2017-07-02 00:13   504394       C       405490
# 107          72843  2017-07-02 00:13   963568       C       405490
# 119         103188  2017-07-02 00:14   172910       C       405490
# 129         305918  2017-07-02 00:16   908696       C       360936
# 149         319808  2017-07-02 00:18  1011276       H       359520
# 173         175741  2017-07-02 00:23   880382       C       359520
# 183           1867  2017-07-02 00:24   529719       I       404347
# 189           9467  2017-07-02 00:25   110660       I       105960
# 204         494661  2017-07-02 00:27   536975       H       359520
# 239         485755  2017-07-02 00:32   966565       H       359520
# ...

# %%
train.describe()
# Out:
#           session_id       user_id    campaign_id     webpage_id  \
# count  463291.000000  4.632910e+05  463291.000000  463291.000000
# mean   285544.090725  5.460497e+05  308474.540069   29685.878994
# std    168577.345887  3.294625e+05  126517.101294   21542.053106
# min         2.000000  4.000000e+00   82320.000000    1734.000000
# 25%    137856.500000  2.578550e+05  118601.000000   13787.000000
# 50%    285429.000000  5.318010e+05  359520.000000   13787.000000
# 75%    435535.500000  8.278490e+05  405490.000000   53587.000000
# max    595812.000000  1.141729e+06  414149.000000   60305.000000
#
#        product_category_1  product_category_2  user_group_id      age_level  \
# count       463291.000000        97437.000000  445048.000000  445048.000000
# mean             3.072427       162753.345105       3.477396       2.782266
# std              1.304233        78743.742720       2.412889       1.069701
# ...

# %%
train.describe(include='all')
# Out:
#            session_id          DateTime       user_id product    campaign_id  \
# count   463291.000000            463291  4.632910e+05  463291  463291.000000
# unique            NaN              8610           NaN      10            NaN
# top               NaN  2017-07-04 20:39           NaN       C            NaN
# freq              NaN               173           NaN  163501            NaN
# mean    285544.090725               NaN  5.460497e+05     NaN  308474.540069
# std     168577.345887               NaN  3.294625e+05     NaN  126517.101294
# min          2.000000               NaN  4.000000e+00     NaN   82320.000000
# 25%     137856.500000               NaN  2.578550e+05     NaN  118601.000000
# 50%     285429.000000               NaN  5.318010e+05     NaN  359520.000000
# 75%     435535.500000               NaN  8.278490e+05     NaN  405490.000000
# max     595812.000000               NaN  1.141729e+06     NaN  414149.000000
#
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
#plt.figure(figsize=(40,40)) 
# play with the figsize until the plot is big enough to plot all the columns
# of your dataset, or the way you desire it to look like otherwise

sns.heatmap(train.corr())

# %% [markdown]
# ##### Count the Null Columns

# %%
null_columns=train.columns[train.isnull().any()]
train[null_columns].isnull().sum()
# Out:
# product_category_2        365854
# user_group_id              18243
# gender                     18243
# age_level                  18243
# user_depth                 18243
# city_development_index    125129
# dtype: int64

# %%
null_columns
# Out:
# Index(['product_category_2', 'user_group_id', 'gender', 'age_level',
#        'user_depth', 'city_development_index'],
#       dtype='object')

# %%
#plt.figure(figsize=(80,80)) 
hist = train.hist()

# %%
#plt.figure();
train.iloc[5]#.plt(kind='bar');
# Out:
# session_id                          151475
# DateTime                  2017-07-02 00:01
# user_id                             509591
# product                                  I
# campaign_id                         359520
# webpage_id                           13787
# product_category_1                       2
# product_category_2                     NaN
# user_group_id                            1
# gender                                Male
# age_level                                1
# user_depth                               3
# city_development_index                 NaN
# var_1                                    0
# is_click                                 0
# Name: 5, dtype: object

# %%
train.columns
# Out:
# Index(['session_id', 'DateTime', 'user_id', 'product', 'campaign_id',
#        'webpage_id', 'product_category_1', 'product_category_2',
#        'user_group_id', 'gender', 'age_level', 'user_depth',
#        'city_development_index', 'var_1', 'is_click'],
#       dtype='object')

# %%
pd.options.display.mpl_style = 'default'
train.boxplot()
# Out:
# C:\ProgramData\Anaconda3x\lib\site-packages\IPython\core\interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
train.groupby('is_click').hist()
# Out:
# is_click
# 0    [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# 1    [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# dtype: object

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(train, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000026C238D0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000266CA0F0>]], dtype=object)

# %%
train.hist(train["is_click"],,margins=True)
# Out:
#   File "<ipython-input-54-ffc6db11c50f>", line 1
#     train.hist(train["is_click"],,margins=True)
#                                  ^
# SyntaxError: invalid syntax

# %%
train['is_click'].hist()
