# %% [markdown]
# ### Loop over columns:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.DataFrame(np.random.randn(14,5), columns=list("ABCDE"))
df
# Out:
#            A         B         C         D         E
# 0  -1.232863 -0.161413  2.462859  0.400774 -0.591693
# 1  -0.063049  1.909191 -0.137286  0.884677  1.107073
# 2   0.921171  0.481898 -0.845070 -0.786735  1.063772
# 3   2.208181 -1.275994  0.858388  0.483921  1.336860
# 4  -1.521011 -0.245036 -0.266642  0.368897  0.877195
# 5   1.374283  2.188248 -0.073421 -0.218927  1.041379
# 6  -0.215292 -0.740269 -0.032882 -1.247739 -0.078038
# 7  -1.007876 -0.548612  0.727132 -0.989251 -0.403077
# 8  -0.701500  0.389936  0.464336 -0.486192  0.311567
# 9   0.238695 -1.294846  0.084789 -0.605079  1.701805
# 10 -1.544696  0.349674  1.600755  0.937651 -0.497607
# 11 -0.691647  0.556342 -1.506589 -0.127514  1.651776
# 12 -0.597005 -0.313779  1.166345  0.810645  0.220588
# 13  0.964389  1.712579 -0.387194 -0.859249 -0.099292

# %%
fig, axes = plt.subplots(ncols=5)
for ax, col in zip(axes, df.columns):
    sns.distplot(df[col], ax=ax)
plt.show()

# %%
g = sns.FacetGrid(df.melt(), col="variable")
g.map(sns.distplot, "value")

plt.show()
